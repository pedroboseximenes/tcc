# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
import sys, os
import seaborn as sns
sys.path.append(os.path.abspath(".."))
import access_br_dwgd as access_br_dwgd
sys.path.append(os.path.abspath("../.."))
from utils.utilDataset import criar_data_frame_chuva_br_dwgd

# %%
#Precipitation (pr, mm);
timeseries = access_br_dwgd.recuperar_dados_br_dwgd_com_area()
datas = timeseries.index 
plt.plot(timeseries['chuva'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()
# Out:
# Melhor estação (ID): A621

# %%
#Precipitation (pr, mm);
datas = timeseries.index 
plt.plot(timeseries['Tmax'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

plt.plot(timeseries['Tmin'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

# %%
plt.plot(timeseries['Rs'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

plt.plot(timeseries['RH'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()


plt.plot(timeseries['u2'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

# %%
#Precipitation (pr, mm);
timeseries, colunas_normalizar = criar_data_frame_chuva_br_dwgd(df=timeseries, tmax_col='Tmax', tmin_col='Tmin', W=30,wet_thr=1.0)
print(timeseries.info())

print(timeseries.isna().sum() / len(timeseries))
#print(timeseries.info())
#print(timeseries.describe())

total_zeros = (timeseries == 0).sum().sum()
print(total_zeros)

total_num = (timeseries > 0).sum().sum()
print(total_num)

sns.boxplot(timeseries)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5924 entries, 2008-01-01 to 2024-03-20
# Freq: D
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chuva        5924 non-null   float32
#  1   RH           5924 non-null   float32
#  2   Rs           5924 non-null   float32
#  3   u2           5924 non-null   float32
#  4   doy_sin      5924 non-null   float64
#  5   doy_cos      5924 non-null   float64
#  6   SDII_30d     5684 non-null   float64
#  7   R10mm_30d    5924 non-null   float64
#  8   R20mm_30d    5924 non-null   float64
#  9   Rx1day_30d   5924 non-null   float64
#  10  Rx5day_30d   5924 non-null   float64
#  11  PRCPTOT_30d  5924 non-null   float64
#  12  Tmed         5924 non-null   float32
# dtypes: float32(5), float64(8)
# memory usage: 532.2 KB
# None
# chuva          0.000000
# RH             0.000000
# Rs             0.000000
# u2             0.000000
# doy_sin        0.000000
# doy_cos        0.000000
# SDII_30d       0.040513
# R10mm_30d      0.000000
# R20mm_30d      0.000000
# Rx1day_30d     0.000000
# Rx5day_30d     0.000000
# PRCPTOT_30d    0.000000
# Tmed           0.000000
# dtype: float64
# 8645
# 62287
# <Axes: >

# %%
plt.figure(figsize=(12,5))
plot_acf(timeseries["chuva"], lags=60)   # 60 lags = 60 dias
plt.title("Autocorrelation Function (ACF) da Precipitação")
plt.show()

# %%
import seaborn as sns

corr = timeseries.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()
