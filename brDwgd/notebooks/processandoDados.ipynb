# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
import sys, os
import seaborn as sns
sys.path.append(os.path.abspath(".."))
import access_br_dwgd as access_br_dwgd

# %%
#Precipitation (pr, mm);
timeseries = access_br_dwgd.recuperar_dados_br_dwgd_com_area()
datas = timeseries.index 
plt.plot(timeseries['chuva'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()
# Out:
# Melhor estação (ID): A621

# %%
#Precipitation (pr, mm);
datas = timeseries.index 
plt.plot(timeseries['Tmax'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

plt.plot(timeseries['Tmin'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

# %%
plt.plot(timeseries['Rs'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

plt.plot(timeseries['RH'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()


plt.plot(timeseries['u2'])
plt.title('Daily Rain in station')
plt.xlabel('Date')
plt.ylabel('mm')
plt.show()

# %%
#Precipitation (pr, mm);
print(timeseries.info())

print(timeseries.isna().sum() / len(timeseries))
#print(timeseries.info())
print(timeseries.describe())

total_zeros = (timeseries == 0).sum().sum()
print(total_zeros)

total_num = (timeseries > 0).sum().sum()
print(total_num)

sns.boxplot(timeseries)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5924 entries, 2008-01-01 to 2024-03-20
# Freq: D
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   chuva   5924 non-null   float32
#  1   Tmax    5924 non-null   float32
#  2   Tmin    5924 non-null   float32
#  3   RH      5924 non-null   float32
#  4   Rs      5924 non-null   float32
#  5   u2      5924 non-null   float32
# dtypes: float32(6)
# memory usage: 185.1 KB
# None
# chuva    0.0
# Tmax     0.0
# Tmin     0.0
# RH       0.0
# Rs       0.0
# u2       0.0
# dtype: float64
#              chuva         Tmax         Tmin           RH           Rs  \
# count  5924.000000  5924.000000  5924.000000  5924.000000  5924.000000
# mean      3.127312    28.510044    18.516340    65.811371    15.830553
# std       9.702062     7.596075     5.294351    23.577909     7.550137
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000    26.200001    16.400000    63.916668    10.383482
# 50%       0.000000    29.600000    19.700001    72.166664    15.938870
# 75%       1.000000    32.900002    22.100000    78.625000    21.401243
# max     154.399994    42.500000    27.900000    99.099998    32.839699
#
#                 u2
# count  5924.000000
# mean      0.940031
# std       0.454632
# min       0.000000
# 25%       0.646875
# 50%       0.909375
# 75%       1.187500
# max       3.481250
# 5263
# 30281
# <Axes: >

# %%
plt.figure(figsize=(12,5))
plot_acf(timeseries["chuva"], lags=60)   # 60 lags = 60 dias
plt.title("Autocorrelation Function (ACF) da Precipitação")
plt.show()
